# %%
import pandas as pd
import numpy as np

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Check folder files
# %cd "/content/drive/Shareddrives/C23-PS139-ML/data"
# %ls -al
# Out:
# /content/drive/Shareddrives/C23-PS139-ML/data
# total 77
# -rw------- 1 root root 77894 May 30 12:56 destination.csv

# %%
# load dataset
df = pd.read_csv('/content/drive/Shareddrives/C23-PS139-ML/data/destination.csv')
df.head()
# Out:
#                                      id                        name  \
# 0  8837ac4d-72cc-4b98-a9c4-3117e630642c       Tourism Village Duchy
# 1  aaf158b8-adb6-4e5d-92fe-c57038847404  Pondok Rasa Teras cipayung
# 2  b14ecb2f-cb9a-43d2-bce2-7389846d6955                Casa Familia
# 3  accf30e5-1a24-470c-8c56-8c78ddf157ea              Penginapan Rio
# 4  8bd10ea5-d9a4-4a8b-956b-ee7fcf036feb       Bukit Panguk Kediwung
#
#                                              map_url  \
# 0  https://www.google.com/maps/place/Tourism+Vill...
# 1  https://www.google.com/maps/place/Pondok+Rasa+...
# 2  https://www.google.com/maps/place/Casa+Familia...
# 3  https://www.google.com/maps/place/Penginapan+R...
# 4                                                NaN
#
#                                              img_url  rating  total_review  \
# 0  https://lh5.googleusercontent.com/p/AF1QipNwrj...     4.4          42.0
# 1  https://lh5.googleusercontent.com/p/AF1QipMrjA...     4.4         812.0
# ...

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 61.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 56.9 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

# %%
tokenizer1 = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model1 = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")
ner1 = pipeline("ner", model=model1, tokenizer=tokenizer1)


tokenizer = AutoTokenizer.from_pretrained("cahya/bert-base-indonesian-NER")
model = AutoModelForTokenClassification.from_pretrained("cahya/bert-base-indonesian-NER")

ner = pipeline("ner", model=model, tokenizer=tokenizer)

# %%
example = "Saya ingin liburan ke kulon progo selama tiga hari"

# %%
ner_results = ner(example)
# print(ner_results)
ner_results
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity': 'B-LOC',
#   'score': 0.86469996,
#   'index': 5,
#   'word': 'kulon',
#   'start': 22,
#   'end': 27},
#  {'entity': 'I-LOC',
#   'score': 0.90692097,
#   'index': 6,
#   'word': 'progo',
#   'start': 28,
#   'end': 33},
#  {'entity': 'B-QTY',
#   'score': 0.9715217,
#   'index': 8,
#   'word': 'tiga',
#   'start': 41,
#   'end': 45},
#  {'entity': 'I-QTY',
#   'score': 0.9737994,
#   'index': 9,
#   'word': 'hari',
#   'start': 46,
#   'end': 50}]

# %%
ner_results[0]
# Out:
# {'entity': 'B-GPE',
#  'score': 0.98306733,
#  'index': 5,
#  'word': 'jakarta',
#  'start': 22,
#  'end': 29}

# %%
ner_results = ner1(example1)
print(ner_results)
# Out:
# [{'entity': 'B-PER', 'score': 0.9990139, 'index': 4, 'word': 'Wolfgang', 'start': 11, 'end': 19}, {'entity': 'B-LOC', 'score': 0.999645, 'index': 9, 'word': 'Berlin', 'start': 34, 'end': 40}]

# %%
from transformers import pipeline

pretrained_name = "w11wo/indonesian-roberta-base-posp-tagger"

# %%
nlp = pipeline(
    "token-classification",
    model=pretrained_name,
    tokenizer=pretrained_name
)

# %%
kata ="Aku lagi di Jogja. Aku ingin ke tempat yang ramai. Selain itu, aku ingin membeli barang-barang antik juga. Tolong tambahkan Parangtritis juga di jadwalnya ya"
nlp(kata)
# Out:
# [{'entity': 'B-PRN',
#   'score': 0.891672,
#   'index': 0,
#   'word': 'ĠAku',
#   'start': 0,
#   'end': 3},
#  {'entity': 'B-ADV',
#   'score': 0.862793,
#   'index': 1,
#   'word': 'Ġlagi',
#   'start': 4,
#   'end': 8},
#  {'entity': 'B-PPO',
#   'score': 0.9990965,
#   'index': 2,
#   'word': 'Ġdi',
#   'start': 9,
#   'end': 11},
#  {'entity': 'B-NNP',
#   'score': 0.99689615,
#   'index': 3,
#   'word': 'ĠJogja',
#   'start': 12,
#   'end': 17},
#  {'entity': 'B-NNP',
#   'score': 0.7313682,
#   'index': 4,
#   'word': '.',
#   'start': 17,
#   'end': 18},
#  {'entity': 'B-PRN',
#   'score': 0.96657693,
#   'index': 5,
#   'word': 'ĠAku',
#   'start': 19,
#   'end': 22},
#  {'entity': 'B-ADV',
#   'score': 0.9771648,
#   'index': 6,
#   'word': 'Ġingin',
#   'start': 23,
#   'end': 28},
#  {'entity': 'B-PPO',
#   'score': 0.998552,
#   'index': 7,
#   'word': 'Ġke',
#   'start': 29,
#   'end': 31},
#  {'entity': 'B-PRR',
#   'score': 0.89115834,
#   'index': 8,
# ...

# %%
# !pip install spacy

# %%
# !pip show spacy

# %%
# import spacy
# from spacy import load, display
# from spacy.util import minibatch, compounding
# from pathlib import Path
# import pickle
# import random
